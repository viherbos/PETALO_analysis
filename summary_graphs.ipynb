# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
import fit_library
sys.path.append("../PETALO_simulation/SimLib")
import config_sim as CFG
import csv
# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

# %%
# Effect of TE_L1
TE_L1 = [4,5,6,7]
WC_L1_B_FIFO = [67.19, 37.5, 25, 18.75]
MIN_OUTSPEED = [500,450,375,325]
#MIN_OUT_n
fig = plt.figure(figsize=(10,8))
axis_TE_L1 = fig.add_subplot(222)
#ax2 = axis_TE_L1.twinx()
axis_TE_L1.set_title("L1 Output FIFO (Depth=128, TOFPET2=12)",size=13)
axis_TE_L1.set_ylabel("Maximum Level in Percentaje \n (700 Mbps outrate)",size=12)
axis_TE_L1.set_xlabel("TE$_{L1}$ (Photons)",size=12)

axis_TE_L1.plot(TE_L1,WC_L1_B_FIFO)

#MIN OUTPUT RATE
ax2 = fig.add_subplot(224)
ax2.set_title("L1 Output FIFO (Depth=128, TOFPET2=12)",size=13)
ax2.set_ylabel("Output rate in Mbps",size=12)
ax2.set_xlabel("TE$_{L1}$ (Photons)",size=12)
ax2.plot(TE_L1,MIN_OUTSPEED,'r-')

# Effect of TE_ASIC
TE_ASIC = [1,2,3]
WC_L1_A_FIFO = [77.00, 63.1, 55.7]
axis_TE_ASIC = fig.add_subplot(221)
axis_TE_ASIC.set_title("L1 Input FIFO (Depth=512, TOFPET2=12)",size=13)
axis_TE_ASIC.set_ylabel("Maximum Level in Percentaje \n (1.3 Gbs TOFPET2 outrate)",size=12)
axis_TE_ASIC.set_xlabel("TE$_{A}$ (Photons)",size=12)

axis_TE_ASIC.plot(TE_ASIC,WC_L1_A_FIFO)

# Effect of TE_L1
Buffer_size = [256,512,1024,2048]
WC_L1_B_FIFO = [100, 81.25, 67.18, 66.4]

#fig2 = plt.figure(figsize=(10,5))
axis_buffer = fig.add_subplot(223)
axis_buffer.set_title("L1 Output FIFO (Depth=128, TOFPET=12)",size=13)
axis_buffer.set_ylabel("Maximum Level in Percentaje \n (700 Mbps Outrate)",size=12)
axis_buffer.set_xlabel("L1 buffer size",size=12)

axis_buffer.plot(Buffer_size,WC_L1_B_FIFO)
plt.show()



fig.tight_layout()
plt.show()
plt.savefig("trends.pdf")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Out:
# <img src="data:image/png;base64,..." width="1000">
