# %%
import numpy as np
import scipy as sp
import pandas as pd
import random
import matplotlib.pyplot as plt
import sys
import os
import fit_library as ft
import open_data

# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

# %%
def analyze(DATA,channel=1,Low_th=-100,High_th=10000):

    Q_fit = ft.gauss_fit()
    data_fit = DATA['Q'][((DATA['id']==channel) & (DATA['Q']>Low_th) & (DATA['Q']<High_th))]
    print data_fit.shape
    Q_fit(data_fit,'sqrt')
    fig = plt.figure()
    ax0 = fig.add_subplot(111)
    Q_fit.plot(axis = ax0, 
               title = "Channel 1 - QDC",
               xlabel = "Code (LSB)",ylabel = "Hits")

# %%
DATA = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_48_R12_1.hdf",key='data')
# Esto es lo que sale con el ratio de actividad del Dark Count

# %%
Low_th  = -25
High_th = 100
channel = 47


Q1_fit = ft.gauss_fit()
data_fit = DATA['Q'][((DATA['id']==channel) & (DATA['Q']>Low_th) & (DATA['Q']<High_th))]
print data_fit.shape
Q1_fit(data_fit,100)
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q1_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (1155,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA2 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_48_R13_1.hdf",key='data')

# %%
Low_th  = -25
High_th = 100
channel = 47


Q2_fit = ft.gauss_fit()
data_fit2 = DATA2['Q'][((DATA2['id']==channel) & (DATA2['Q']>Low_th) & (DATA2['Q']<High_th))]
print data_fit2.shape
Q2_fit(data_fit2,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q2_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (5734,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA2 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_49_R2_1.hdf",key='data')

# %%
Low_th  = -25
High_th = 100
channel = 47


Q2_fit = ft.gauss_fit()
data_fit2 = DATA2['Q'][((DATA2['id']==channel) & (DATA2['Q']>Low_th) & (DATA2['Q']<High_th))]
print data_fit2.shape
Q2_fit(data_fit2,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q2_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (108480,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA3 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_49_R3_1.hdf",key='data')

# %%
Low_th  = -25
High_th = 100
channel = 47


Q3_fit = ft.gauss_fit()
data_fit3 = DATA3['Q'][((DATA3['id']==channel) & (DATA3['Q']>Low_th) & (DATA3['Q']<High_th))]
print data_fit3.shape
Q3_fit(data_fit3,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q3_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (21138,)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # LED OFF - TH1=20 - TH2=20 - THE=11

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_49_R5_1.hdf",key='data')

# %%
Low_th  = -25
High_th = 100
channel = 47


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (9706,)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # LED ON (2.670) - TH1=20 - TH2=20 - THE=11

# %%
DATA4 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_49_ON_R6_1.hdf",key='data')

# %%
Low_th  = -25
High_th = 100
channel = 47


Q4_fit = ft.gauss_fit()
data_fit4 = DATA4['Q'][((DATA4['id']==channel) & (DATA4['Q']>Low_th) & (DATA4['Q']<High_th))]
print data_fit4.shape
Q4_fit(data_fit4,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q4_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (1116,)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # LED ON (2.750) - TH1=20 - TH2=20 - THE=11

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_EXT_49_ON_R8_1.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 47


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (11098,)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_TEST_ON_5.hdf",key='data')

# %%
Low_th  = -5
High_th = 200
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (74930,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_TEST_ON_6.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (72894,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED 3.15

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_TEST_ON_7.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (74640,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED 3.05

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_TEST_ON_8.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (42808,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED 3.0 V

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_TEST_ON_9.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (355,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED OFF

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_TEST_ON_10.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (27,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED: 3.150

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_LED_315_11.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (72417,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_LED_305_4.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (2670,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED 3.05 VDD=49.5

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_LED_305_5.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (4881,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_LED_300_495_10.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (65913,)
# <img src="data:image/png;base64,..." width="640">

# %%
# LED 290

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_LED_290_495_11.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (2833,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_HAMA_LED_290_495_EXT_12.hdf",key='data')

# %%
Low_th  = -5
High_th = 100
channel = 45


Q5_fit = ft.gauss_fit()
data_fit5 = DATA5['Q'][((DATA5['id']==channel) & (DATA5['Q']>Low_th) & (DATA5['Q']<High_th))]
print data_fit5.shape
Q5_fit(data_fit5,'sqrt')
fig = plt.figure()
ax0 = fig.add_subplot(111)
Q5_fit.plot(axis = ax0, 
            title = "Channel 1 - QDC",
            xlabel = "Code (LSB)",ylabel = "Hits")
# Out:
# (4193,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA5 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H0_H23_1.hdf",key='data')

# %%
analyze(DATA5,channel=1,Low_th=-100,High_th=10000)
# Out:
# (319978,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H1_H23_2.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (293739,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H2_H23_3.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (294227,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H3_H23_4.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (287277,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H4_H23_5.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (290397,)
# <img src="data:image/png;base64,..." width="749">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H5_H23_6.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (293729,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H6_H23_7.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (254745,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H6_H38_8.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (187684,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H7_H38_9.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (173412,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H7_H23_10.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (69004,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H5_H38_11.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (247886,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H4_H38_12.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (289886,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H3_H38_14.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (288419,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H2_H38_15.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (202224,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H1_H38_16.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (286462,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_H0_H38_17.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (294344,)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # -----------------------------------------------------------------------------------------------

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_GAIN_1.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (282782,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_GAIN_2.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (294785,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_GAIN_3.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (147422,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_GAIN_4.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (148967,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_GAIN_13.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (448,)
# <img src="data:image/png;base64,..." width="640">

# %%
DATA6 = pd.read_hdf("/home/viherbos/DAQ_DATA/c_TEST_G2_18.hdf",key='data')
analyze(DATA6,channel=1,Low_th=-100,High_th=10000)
# Out:
# (1041,)
# <img src="data:image/png;base64,..." width="640">
