# %%
import numpy as np
import scipy as sp
import pandas as pd
import random
import matplotlib.pyplot as plt
import sys
import os
import fit_library
sys.path.append("../PETALO_DAQ_infinity/SimLib")
import config_sim as CFG
import csv
# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

# %%
mu = 100
timing = np.random.poisson(mu,1000).astype(int)

# %%
fit = fit_library.gauss_fit()
fig = plt.figure()
fit(timing,10)
fit.plot(fig.add_subplot(111),'','','',res=True,fit=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
