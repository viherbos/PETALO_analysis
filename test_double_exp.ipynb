# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import fit_library as fit_lib
# %load_ext autoreload
# %autoreload 2

# %%
time = np.arange(0,80000,5)
param = [1000,1500,1,10000,8000,15000,0.25,10000]

# %%
target = fit_lib.Ddouble_exp(time,*param)

# %%
fig = plt.figure()
plt.plot(time,target)
plt.show()

# %%
fit = fit_lib.Ddouble_exp_fit()
fig2 = plt.figure()
fit(target,time,[250,15000,1,10000,250,15000,1,30000])
fit.plot(axis = fig2.add_subplot(111),
         title = "",
         xlabel = "",
         ylabel = "",
         res=False, 
         fit=True)
plt.show()
