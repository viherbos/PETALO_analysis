# %%
import fit_library_n as ft_n
import fit_library as ft
import pandas as pd
import random
import matplotlib.pyplot as plt
import sys
import os
import open_data
import numpy as np

# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

# %%
def analyze(DATA,channel=1,Low_th=-100,High_th=10000,bins='sqrt'):

    Q_fit = ft.gauss_fit()
    data_fit = DATA['Q'][((DATA['id']==channel) & (DATA['Q']>Low_th) & (DATA['Q']<High_th))]
    #print data_fit.shape
    Q_fit(data_fit,bins)
    fig = plt.figure()
    ax0 = fig.add_subplot(111)
    Q_fit.plot(axis = ax0, 
               title = "Channel 1 - QDC",
               xlabel = "Code (LSB)",ylabel = "Hits")
    return Q_fit.p0[1],Q_fit.p0[2]

def analyze2(DATA,channel=1,Low_th=-100,High_th=10000,bins='sqrt',mu1=168,mu2=168,sigma=2):

    Q_fit = ft.gauss_fit2()
    data_fit = DATA['Q'][((DATA['id']==channel) & (DATA['Q']>Low_th) & (DATA['Q']<High_th))]
    #print data_fit.shape
    Q_fit(data_fit,[mu1,mu2,sigma,sigma],bins)
    fig = plt.figure()
    ax0 = fig.add_subplot(111)
    Q_fit.plot(axis = ax0, 
               title = "Channel 1 - QDC",
               xlabel = "Code (LSB)",ylabel = "Hits")
    return Q_fit.coeff[1],Q_fit.coeff[2]

# %%
mu_w10=np.zeros(6)
sigma_w10=np.zeros(6)

# %%
mu_w10[0],sigma_w10[0] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_2.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w10[1],sigma_w10[1] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_3.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=30)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w10[2],sigma_w10[2] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_4.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w10[3],sigma_w10[3] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_5.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w10[4],sigma_w10[4] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_7.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w10[5],sigma_w10[5] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_6.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pe = np.array([0,4.4,25.5,72.45,124.1,214.1])
#pe = [0,4,25,72,124,214]
ft_n.line_fit(mu_w10,pe,sigma_w10,"Expected PEs","Counts (LSB)","Linearity & Dynamic Range",0,1)
# Out:
# Max Linearity Error = 2.323%
# <img src="data:image/png;base64,..." width="640">
# ('Fitted A = ', 0.27797396139525493, '( Error_std=', 0.021129220863428545, ')')
# ('Fitted B = ', 171.08601244892648, '( Error_std=', 2.2354115218754478, ')')
# (array([   0.27797396,  171.08601245]),
#  array([ 0.02112922,  2.23541152]),
#  0.65309132341135401)

# %%
mu_w15=np.zeros(6)
sigma_w15=np.zeros(6)

# %%
mu_w15[0],sigma_w15[0] = analyze(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_9.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w15[1],sigma_w15[1] = analyze2(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_10.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=60,mu1=257,mu2=254.7,sigma=2.8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w15[2],sigma_w15[2] = analyze2(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_11.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=75,mu1=265,mu2=254.7,sigma=2.8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w15[3],sigma_w15[3] = analyze2(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_12.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70,mu1=275,mu2=254.7,sigma=2.8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w15[4],sigma_w15[4] = analyze2(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_13.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70,mu1=275,mu2=254.7,sigma=2.8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mu_w15[5],sigma_w15[5] = analyze2(pd.read_hdf("/home/viherbos/DAQ_DATA/c_OPT_GAIN_15.hdf",key='data'),channel=1,Low_th=0,High_th=500,bins=70,mu1=310,mu2=254.7,sigma=2.8)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pe = np.array([0,4.4,25.5,72.45,124.1,214.1])
#pe = [0,4,25,72,124,214]

ft_n.line_fit(mu_w15[0:4],pe[0:4],sigma_w15[0:4],"Expected PEs","Counts (LSB)","Linearity & Dynamic Range - CONSTANT INT. WINDOW = 15",31,1)
ft_n.line_fit(mu_w10,pe,sigma_w10,"Expected PEs","Counts (LSB)","Linearity & Dynamic Range - CONSTANT INT. WINDOW = 10",32,1)
# Out:
# Max Linearity Error = 0.204%
# <img src="data:image/png;base64,..." width="640">
# ('Fitted A = ', 0.45329461555841971, '( Error_std=', 0.0089181188504752675, ')')
# ('Fitted B = ', 255.45979316277555, '( Error_std=', 0.3430466591206609, ')')
# Max Linearity Error = 2.323%
# <img src="data:image/png;base64,..." width="640">
# ('Fitted A = ', 0.27797396139525493, '( Error_std=', 0.021129220863428545, ')')
# ('Fitted B = ', 171.08601244892648, '( Error_std=', 2.2354115218754478, ')')
# (array([   0.27797396,  171.08601245]),
#  array([ 0.02112922,  2.23541152]),
#  0.65309132341135401)

# %%
print sigma_w10
# Out:
# [ 2.87377399  3.21399662  4.08890117  5.48306013  8.06091927  8.20630219]
